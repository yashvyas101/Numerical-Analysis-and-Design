# %% [markdown]
# # Assignment No. 2
#
# Name: yash vyas<br>
# Roll No.: IT-2K24-97
#
# ## Question 4: Numerical Quadrature

# %% [markdown]
# ### Method 4.1: Newton-Cotes Formula (Simpson 1/3 Rule)

# %%
def simpson_one_third_rule(func, a, b, n):
    if n % 2 != 0:
        raise ValueError("n must be even for Simpson 1/3 rule.")

    h = (b - a) / n
    total = func(a) + func(b)

    for i in range(1, n):
        coefficient = 4 if i % 2 == 1 else 2
        total += coefficient * func(a + i * h)

    return (h / 3) * total


def f_quad(x):
    return x**2


approx_integral = simpson_one_third_rule(f_quad, 0.0, 1.0, 10)
print("Approximate integral:", approx_integral)
# Out:
# Approximate integral: 0.3333333333333333

# %% [markdown]
# Time Complexity: O(n)
#
# Space Complexity: O(1)

# %% [markdown]
# ### Method 4.2: Gauss Quadrature Formula (2-Point)

# %%
def gauss_quadrature_two_point(func, a, b):
    t1 = -1.0 / (3.0 ** 0.5)
    t2 = 1.0 / (3.0 ** 0.5)

    x1 = (a + b) / 2.0 + (b - a) * t1 / 2.0
    x2 = (a + b) / 2.0 + (b - a) * t2 / 2.0

    return (b - a) / 2.0 * (func(x1) + func(x2))


def f_quad(x):
    return x**2


approx_integral = gauss_quadrature_two_point(f_quad, 0.0, 1.0)
print("Approximate integral:", approx_integral)
# Out:
# Approximate integral: 0.3333333333333333

# %% [markdown]
# Time Complexity: O(1)
#
# Space Complexity: O(1)
